# %%
"""Логирование."""

# %% [markdown]
# 23.02.2026
#
# 1. Зарегистрировался на ОДС, кворке, воркзилле
# 2. Написал в чат сообщение о себе
# 3. Отправил подписанный договор в чат
# 4. Скачал гитхаб десктоп
# 5. Установил плагины в вс код
# 6. Скачал миниконду и создал окружение
# 7. Сделал джамборд для учебы и скинул ссылку на него
# 8. Поставил звезду репозиторию, принял приглашение в команду, подписался на коллег в гитхабе и каггле
# 9. Сделал форк, открыл репозиторий в гитхаб декстопе и вс коде, запустил нужные команды
# 10. Прислал скриншот терминала в чат
